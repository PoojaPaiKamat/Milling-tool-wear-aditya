# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

# %%
#Mounting drive on COLAB NOTEBOOK This whole project is online, so mounting google drive.
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
data_df1 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/CNC_data/experiment_1.csv', header = 0)
# Removing unwanted parameters
data_df1.drop(data_df1.iloc[:,0:32], inplace = True, axis = 1)
data_df1.drop(data_df1.iloc[:,3:6], inplace = True, axis = 1)
data_df1 = data_df1.drop('Machining_Process', axis=1)
data_df1 = data_df1.drop('M1_sequence_number', axis=1)
data_df1 = data_df1.drop('M1_CURRENT_PROGRAM_NUMBER', axis=1)
#data_df1.insert(loc=0, column='row_num', value=np.arange(len(data_df1)))
data_df1  

data_df2 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/CNC_data/experiment_2.csv', header = 0)
# Removing unwanted parameters
data_df2.drop(data_df2.iloc[:,0:32], inplace = True, axis = 1)
data_df2.drop(data_df2.iloc[:,3:6], inplace = True, axis = 1)
data_df2 = data_df2.drop('Machining_Process', axis=1)
data_df2 = data_df2.drop('M1_sequence_number', axis=1)
data_df2 = data_df2.drop('M1_CURRENT_PROGRAM_NUMBER', axis=1)
#data_df2.insert(loc=0, column='row_num', value=np.arange(len(data_df2)))
data_df2

data_df3 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/CNC_data/experiment_3.csv', header = 0)
# Removing unwanted parameters
data_df3.drop(data_df3.iloc[:,0:32], inplace = True, axis = 1)
data_df3.drop(data_df3.iloc[:,3:6], inplace = True, axis = 1)
data_df3 = data_df3.drop('Machining_Process', axis=1)
data_df3 = data_df3.drop('M1_sequence_number', axis=1)
data_df3 = data_df3.drop('M1_CURRENT_PROGRAM_NUMBER', axis=1)
#data_df3.insert(loc=0, column='row_num', value=np.arange(len(data_df3)))
data_df3 

data_df4 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/CNC_data/experiment_4.csv', header = 0)
# Removing unwanted parameters
data_df4.drop(data_df4.iloc[:,0:32], inplace = True, axis = 1)
data_df4.drop(data_df4.iloc[:,3:6], inplace = True, axis = 1)
data_df4 = data_df4.drop('Machining_Process', axis=1)
data_df4 = data_df4.drop('M1_sequence_number', axis=1)
data_df4 = data_df4.drop('M1_CURRENT_PROGRAM_NUMBER', axis=1)
#data_df4.insert(loc=0, column='row_num', value=np.arange(len(data_df4)))
data_df4 

data_df5 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/CNC_data/experiment_5.csv', header = 0)
# Removing unwanted parameters
data_df5.drop(data_df5.iloc[:,0:32], inplace = True, axis = 1)
data_df5.drop(data_df5.iloc[:,3:6], inplace = True, axis = 1)
data_df5 = data_df5.drop('Machining_Process', axis=1)
data_df5 = data_df5.drop('M1_sequence_number', axis=1)
data_df5 = data_df5.drop('M1_CURRENT_PROGRAM_NUMBER', axis=1)
#data_df5.insert(loc=0, column='row_num', value=np.arange(len(data_df5)))
data_df5

data_df6 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/CNC_data/experiment_6.csv', header = 0)
# Removing unwanted parameters
data_df6.drop(data_df6.iloc[:,0:32], inplace = True, axis = 1)
data_df6.drop(data_df6.iloc[:,3:6], inplace = True, axis = 1)
data_df6 = data_df6.drop('Machining_Process', axis=1)
data_df6 = data_df6.drop('M1_sequence_number', axis=1)
data_df6 = data_df6.drop('M1_CURRENT_PROGRAM_NUMBER', axis=1)
#data_df5.insert(loc=0, column='row_num', value=np.arange(len(data_df5)))
data_df6

data_df8 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/CNC_data/experiment_8.csv', header = 0)
# Removing unwanted parameters
data_df8.drop(data_df8.iloc[:,0:32], inplace = True, axis = 1)
data_df8.drop(data_df8.iloc[:,3:6], inplace = True, axis = 1)
data_df8 = data_df8.drop('Machining_Process', axis=1)
data_df8 = data_df8.drop('M1_sequence_number', axis=1)
data_df8 = data_df8.drop('M1_CURRENT_PROGRAM_NUMBER', axis=1)
#data_df5.insert(loc=0, column='row_num', value=np.arange(len(data_df5)))
data_df8

data_df10 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/CNC_data/experiment_10.csv', header = 0)
# Removing unwanted parameters
data_df10.drop(data_df10.iloc[:,0:32], inplace = True, axis = 1)
data_df10.drop(data_df10.iloc[:,3:6], inplace = True, axis = 1)
data_df10 = data_df10.drop('Machining_Process', axis=1)
data_df10 = data_df10.drop('M1_sequence_number', axis=1)
data_df10 = data_df10.drop('M1_CURRENT_PROGRAM_NUMBER', axis=1)
#data_df5.insert(loc=0, column='row_num', value=np.arange(len(data_df5)))
data_df10

data_df11 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/CNC_data/experiment_11.csv', header = 0)
# Removing unwanted parameters
data_df11.drop(data_df11.iloc[:,0:32], inplace = True, axis = 1)
data_df11.drop(data_df11.iloc[:,3:6], inplace = True, axis = 1)
data_df11 = data_df11.drop('Machining_Process', axis=1)
data_df11 = data_df11.drop('M1_sequence_number', axis=1)
data_df11 = data_df11.drop('M1_CURRENT_PROGRAM_NUMBER', axis=1)
#data_df5.insert(loc=0, column='row_num', value=np.arange(len(data_df5)))
data_df11

data_df12 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/CNC_data/experiment_12.csv', header = 0)
# Removing unwanted parameters
data_df12.drop(data_df12.iloc[:,0:32], inplace = True, axis = 1)
data_df12.drop(data_df12.iloc[:,3:6], inplace = True, axis = 1)
data_df12 = data_df12.drop('Machining_Process', axis=1)
data_df12 = data_df12.drop('M1_sequence_number', axis=1)
data_df12 = data_df12.drop('M1_CURRENT_PROGRAM_NUMBER', axis=1)
#data_df5.insert(loc=0, column='row_num', value=np.arange(len(data_df5)))
data_df12

data_df13 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/CNC_data/experiment_13.csv', header = 0)
# Removing unwanted parameters
data_df13.drop(data_df13.iloc[:,0:32], inplace = True, axis = 1)
data_df13.drop(data_df13.iloc[:,3:6], inplace = True, axis = 1)
data_df13 = data_df13.drop('Machining_Process', axis=1)
data_df13 = data_df13.drop('M1_sequence_number', axis=1)
data_df13 = data_df13.drop('M1_CURRENT_PROGRAM_NUMBER', axis=1)
#data_df5.insert(loc=0, column='row_num', value=np.arange(len(data_df5)))
data_df13


data_df14 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/CNC_data/experiment_14.csv', header = 0)
# Removing unwanted parameters
data_df14.drop(data_df14.iloc[:,0:32], inplace = True, axis = 1)
data_df14.drop(data_df14.iloc[:,3:6], inplace = True, axis = 1)
data_df14 = data_df14.drop('Machining_Process', axis=1)
data_df14 = data_df14.drop('M1_sequence_number', axis=1)
data_df14 = data_df14.drop('M1_CURRENT_PROGRAM_NUMBER', axis=1)
#data_df5.insert(loc=0, column='row_num', value=np.arange(len(data_df5)))
data_df14

data_df15 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/CNC_data/experiment_15.csv', header = 0)
# Removing unwanted parameters
data_df15.drop(data_df15.iloc[:,0:32], inplace = True, axis = 1)
data_df15.drop(data_df15.iloc[:,3:6], inplace = True, axis = 1)
data_df15 = data_df15.drop('Machining_Process', axis=1)
data_df15 = data_df15.drop('M1_sequence_number', axis=1)
data_df15 = data_df15.drop('M1_CURRENT_PROGRAM_NUMBER', axis=1)
#data_df5.insert(loc=0, column='row_num', value=np.arange(len(data_df5)))
data_df15


data_df16 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/CNC_data/experiment_16.csv', header = 0)
# Removing unwanted parameters
data_df16.drop(data_df16.iloc[:,0:32], inplace = True, axis = 1)
data_df16.drop(data_df16.iloc[:,3:6], inplace = True, axis = 1)
data_df16 = data_df16.drop('Machining_Process', axis=1)
data_df16 = data_df16.drop('M1_sequence_number', axis=1)
data_df16 = data_df16.drop('M1_CURRENT_PROGRAM_NUMBER', axis=1)
#data_df5.insert(loc=0, column='row_num', value=np.arange(len(data_df5)))
data_df16

data_df17 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/CNC_data/experiment_17.csv', header = 0)
# Removing unwanted parameters
data_df17.drop(data_df17.iloc[:,0:32], inplace = True, axis = 1)
data_df17.drop(data_df17.iloc[:,3:6], inplace = True, axis = 1)
data_df17 = data_df17.drop('Machining_Process', axis=1)
data_df17 = data_df17.drop('M1_sequence_number', axis=1)
data_df17 = data_df17.drop('M1_CURRENT_PROGRAM_NUMBER', axis=1)
#data_df5.insert(loc=0, column='row_num', value=np.arange(len(data_df5)))
data_df17


data_df18 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/CNC_data/experiment_17.csv', header = 0)
# Removing unwanted parameters
data_df18.drop(data_df18.iloc[:,0:32], inplace = True, axis = 1)
data_df18.drop(data_df18.iloc[:,3:6], inplace = True, axis = 1)
data_df18 = data_df18.drop('Machining_Process', axis=1)
data_df18 = data_df18.drop('M1_sequence_number', axis=1)
data_df18 = data_df18.drop('M1_CURRENT_PROGRAM_NUMBER', axis=1)
#data_df5.insert(loc=0, column='row_num', value=np.arange(len(data_df5)))
data_df18

frames = [data_df1, data_df2, data_df3, data_df4, data_df5, data_df6, data_df8, data_df10, data_df11, data_df12, data_df13, data_df14, data_df15, data_df16, data_df17, data_df18]
result = pd.concat(frames)
result.reset_index(inplace=True, drop=True)
result.insert(loc=0, column='row_num', value=np.arange(len(result)))
print (result)
# Out:
#        row_num  S1_ActualPosition  ...  S1_SystemInertia  M1_CURRENT_FEEDRATE
# 0            0             -361.0  ...              12.0                 50.0
# 1            1             -361.0  ...              12.0                 50.0
# 2            2             -361.0  ...              12.0                 50.0
# 3            3             -361.0  ...              12.0                 50.0
# 4            4             -361.0  ...              12.0                 50.0
# ...        ...                ...  ...               ...                  ...
# 23873    23873              954.0  ...              12.0                  3.0
# 23874    23874              959.0  ...              12.0                  3.0
# 23875    23875              964.0  ...              12.0                  3.0
# 23876    23876              970.0  ...              12.0                  3.0
# 23877    23877              975.0  ...              12.0                  3.0
#
# [23878 rows x 11 columns]

# %%
titles = [
    "S1_ActualPosition",
    "S1_ActualVelocity",
    "S1_ActualAcceleration",
    "S1_CurrentFeedback",
    "S1_DCBusVoltage",
    "S1_OutputCurrent",
    "S1_OutputVoltage",
    "S1_OutputPower",
    "S1_SystemInertia",
    "M1_CURRENT_FEEDRATE",
]

feature_keys = [
    "S1_ActualPosition",
    "S1_ActualVelocity",
    "S1_ActualAcceleration",
    "S1_CurrentFeedback",
    "S1_DCBusVoltage",
    "S1_OutputCurrent",
    "S1_OutputVoltage",
    "S1_OutputPower",
    "S1_SystemInertia",
    "M1_CURRENT_FEEDRATE",
]

colors = [
    "blue",
    "orange",
    "green",
    "red",
    "purple",
    "brown",
    "pink",
    "gray",
    "olive",
    "cyan",
]

date_time_key = "row_num"


def show_raw_visualization(data):
    time_data = data[date_time_key]
    fig, axes = plt.subplots(
        nrows=5, ncols=2, figsize=(15, 20), dpi=80, facecolor="w", edgecolor="k"
    )
    for i in range(len(feature_keys)):
        key = feature_keys[i]
        c = colors[i % (len(colors))]
        t_data = data[key]
        t_data.index = time_data
        t_data.head()
        ax = t_data.plot(
            ax=axes[i // 2, i % 2],
            color=c,
            title="{} - {}".format(titles[i], key),
            rot=25,
        )
        ax.legend([titles[i]])
    plt.tight_layout()


show_raw_visualization(result)

# %%
def show_heatmap(data):
    plt.matshow(data.corr())
    plt.xticks(range(data.shape[1]), data.columns, fontsize=14, rotation=90)
    plt.gca().xaxis.tick_bottom()
    plt.yticks(range(data.shape[1]), data.columns, fontsize=14)

    cb = plt.colorbar()
    cb.ax.tick_params(labelsize=14)
    plt.title("Feature Correlation Heatmap", fontsize=14)
    plt.show()


show_heatmap(result)

# %%
split_fraction = 0.715
train_split = int(split_fraction * int(result.shape[0]))
step = 2

past = 510
future = 10
learning_rate = 0.008
batch_size = 128
epochs = 25


def normalize(data, train_split):
    data_mean = data[:train_split].mean(axis=0)
    data_std = data[:train_split].std(axis=0)
    return (data - data_mean) / data_std

# %%
print(
    "The selected parameters are:",
    ", ".join([titles[i] for i in [1, 3, 4, 6, 7]]),
)
selected_features = [feature_keys[i] for i in [1, 3, 4, 6, 7]]
features = result[selected_features]
features.index = result[date_time_key]
features.head()

features = normalize(features.values, train_split)
features = pd.DataFrame(features)
features.head()

train_data = features.loc[0 : train_split - 1]
val_data = features.loc[train_split:]
# Out:
# The selected parameters are: S1_ActualVelocity, S1_CurrentFeedback, S1_DCBusVoltage, S1_OutputVoltage, S1_OutputPower

# %%
start = past + future
end = start + train_split

x_train = train_data[[i for i in range(5)]].values
y_train = features.iloc[start:end][[1]]

sequence_length = int(past / step)     
print(x_train.shape)
print(y_train.shape) 
print(x_train)
print(y_train)
# Out:
# (17072, 5)
# (17072, 1)
# [[-1.57129192 -1.36593578 -1.47497357 -1.54603627 -1.50328227]
#  [-1.57133346 -1.44338838 -1.47497357 -1.54603627 -1.50329702]
#  [-1.57133346 -1.36593578 -1.47497357 -1.54603627 -1.50327969]
#  ...
#  [ 0.64656519  0.6062441   0.46887967  0.61000593  0.49832383]
#  [ 0.63825845  0.76839857  0.50041379  0.6285925   0.52243967]
#  [ 0.64241182  0.54901311  0.67610388  0.64717907  0.71536637]]
#               1
# 520    0.692091
# 521    0.797014
# 522    1.149938
# 523    0.453628
# 524    0.386859
# ...         ...
# 17587 -1.480398
# 17588 -1.433182
# 17589 -1.415442
# 17590 -1.377000
# 17591 -1.415442
#
# [17072 rows x 1 columns]

# %%
dataset_train = keras.preprocessing.timeseries_dataset_from_array(
    x_train,
    y_train,
    sequence_length=sequence_length,
    sampling_rate=step,
    batch_size=batch_size,
)

# %%
x_end = len(val_data) - past - future

label_start = train_split + past + future

x_val = val_data.iloc[:x_end][[i for i in range(5)]].values
y_val = features.iloc[label_start:][[1]]

print(x_val)
print(y_val)


dataset_val = keras.preprocessing.timeseries_dataset_from_array(
    x_val,
    y_val,
    sequence_length=sequence_length,
    sampling_rate=step,
    batch_size=batch_size,
)


for batch in dataset_train.take(1):
    inputs, targets = batch

print("Input shape:", inputs.numpy().shape)
print("Target shape:", targets.numpy().shape)
# Out:
# [[ 0.64241182  1.102246    0.57249177  0.64717907  0.58272926]
#  [ 0.64241182  0.56809011  0.38553949  0.6285925   0.4139184 ]
#  [ 0.64241182  0.54901311  0.7256575   0.66576564  0.77565596]
#  ...
#  [-1.57129192 -1.38281892 -1.47497357 -1.54603627 -1.503261  ]
#  [-1.57129192 -1.39712667 -1.47497357 -1.54603627 -1.5032393 ]
#  [-1.57137499 -1.44024068 -1.47497357 -1.54603627 -1.50329529]]
#               1
# 17592 -1.424273
# 17593 -1.441958
# 17594 -1.461225
# 17595  0.367782
# 17596  0.949630
# ...         ...
# 23873  0.014857
# 23874  0.472705
# 23875  0.444090
# 23876  0.253320
# 23877  0.291474
#
# [6286 rows x 1 columns]
# Input shape: (128, 255, 5)
# Target shape: (128, 1)

# %%
inputs = keras.layers.Input(shape=(inputs.shape[1], inputs.shape[2]))
lstm_out = keras.layers.LSTM(32)(inputs)
outputs = keras.layers.Dense(1)(lstm_out)

model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer=keras.optimizers.Adamax(learning_rate=learning_rate), loss="mse")
model.summary()
# Out:
# Model: "functional_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_4 (InputLayer)         [(None, 255, 5)]          0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 32)                4864
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# ...
# Total params: 4,897
# Trainable params: 4,897
# Non-trainable params: 0
# _________________________________________________________________

# %%
path_checkpoint = "model_checkpoint.h5"
es_callback = keras.callbacks.EarlyStopping(monitor="val_loss", min_delta=0, patience=5)

modelckpt_callback = keras.callbacks.ModelCheckpoint(
    monitor="val_loss",
    filepath=path_checkpoint,
    verbose=1,
    save_weights_only=True,
    save_best_only=True,
)

history = model.fit(
    dataset_train,
    epochs=epochs,
    validation_data=dataset_val,)
# Out:
# Epoch 1/25
# 130/130 [==============================] - 20s 156ms/step - loss: 0.8725 - val_loss: 0.6782
# Epoch 2/25
# 130/130 [==============================] - 20s 155ms/step - loss: 0.8599 - val_loss: 0.6079
# Epoch 3/25
# 130/130 [==============================] - 20s 156ms/step - loss: 0.8288 - val_loss: 0.5997
# Epoch 4/25
# 130/130 [==============================] - 20s 156ms/step - loss: 0.8438 - val_loss: 0.6067
# Epoch 5/25
# 130/130 [==============================] - 21s 158ms/step - loss: 0.8184 - val_loss: 0.5986
# Epoch 6/25
# 130/130 [==============================] - 20s 155ms/step - loss: 0.8208 - val_loss: 0.5989
# Epoch 7/25
# 130/130 [==============================] - 20s 156ms/step - loss: 0.8127 - val_loss: 0.5967
# Epoch 8/25
# 130/130 [==============================] - 20s 156ms/step - loss: 0.7989 - val_loss: 0.5975
# Epoch 9/25
# 130/130 [==============================] - 20s 157ms/step - loss: 0.8002 - val_loss: 0.5973
# Epoch 10/25
# ...

# %%
def visualize_loss(history, title):
    loss = history.history["loss"]
    val_loss = history.history["val_loss"]
    epochs = range(len(loss))
    plt.figure()
    plt.plot(epochs, loss, "b", label="Training loss")
    plt.plot(epochs, val_loss, "r", label="Validation loss")
    plt.title(title)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()


visualize_loss(history, "Training and Validation Loss")

# %%
def show_plot(plot_data, delta, title):
    labels = ["History", "True Future", "Model Prediction"]
    marker = [".-", "rx", "go"]
    time_steps = list(range(-(plot_data[0].shape[0]), 0))
    if delta:
        future = delta
    else:
        future = 0

    plt.title(title)
    for i, val in enumerate(plot_data):
        if i:
            plt.plot(future, plot_data[i], marker[i], markersize=10, label=labels[i])
        else:
            plt.plot(time_steps, plot_data[i].flatten(), marker[i], label=labels[i])
    plt.legend()
    plt.xlim([time_steps[0], (future + 0) * 2])
    plt.xlabel("Time-Step")
    plt.show()
    return


for x, y in dataset_val.take(4):
    show_plot(
        [x[0][:, 1].numpy(), np.mean(y.numpy()), np.mean(model.predict(x))],
        12,
        "Single Step Prediction",
    )

# %%
model.save('/content/drive/My Drive/Colab Notebooks/Saved_models/AUTOENCODER_final.h5')

# Recreate the exact same model, including its weights and the optimizer
new_autoencoder = tf.keras.models.load_model('/content/drive/My Drive/Colab Notebooks/Saved_models/AUTOENCODER_final.h5')
